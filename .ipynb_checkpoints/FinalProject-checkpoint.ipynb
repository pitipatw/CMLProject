# %% [markdown]
# ## Toward data-driven topology optimization of concrete structures
# **By Pitipat Wongsittikan, SMBT 24'**
#
# *Final project for Creative Machine Learning for Design, Spring 2023*

# %% [markdown]
# ## 0. Setup
# #### Load required packages

# %%
# for Topology optimization
using TopOpt, LinearAlgebra, StatsFuns  
# for Data Visualization
using Makie, GLMakie 
# for Data Analysis
using CSV , DataFrames
using Clustering
#These are for the surrogate model
using Flux, Zygote , MLJ
using SurrogatesFlux, Surrogates
using Statistics
using Random
using Distributions
# Out:
# WARNING: using GeometryBasics.Tetrahedron in module Visualization conflicts with an existing identifier.
# WARNING: using GeometryBasics.Triangle in module Visualization conflicts with an existing identifier.

# %% [markdown]
# #### Additional settings

# %%
Makie.inline!(true) # so Makie plots are in Jupyter notebook
# Out:
# true

# %% [markdown]
# #### Load and inspect data from the .csv file

# %%
df = CSV.read("Dataset_1.csv", DataFrame)
ndata = size(df)[1]
println("There are $ndata data points in the dataset.")
# println(df[!,"country"])
df_IN = df[df[!,"country"] .== "IN",:];
df_US = df[df[!,"country"] .== "US",:];
df_CA = df[df[!,"country"] .== "CA",:];
df_AU = df[df[!,"country"] .== "AU",:];
df_NZ = df[df[!,"country"] .== "NZ",:];
df_SG = df[df[!,"country"] .== "SG",:];
# Out:
# There are 119533 data points in the dataset.

# %%
#Check headers
foreach(println, names(df))
# Out:
# strength [MPa]
# gwp_per_kg [kgCO2e/kg]
# slope
# Group
# gwp_per_kg_unit
# concrete_compressive_strength_28d_numeric
# concrete_compressive_strength_28d_unit
# Column3
# Column1
# carbon_intensity_numeric
# carbon_intensity_unit
# latitude
# longitude
# name
# address
# country
# id

# %% [markdown]
# #### Data Visualization

# %%
f1 = Figure(resolution = (1200, 800)) 
ax1  = Axis(f1[1,1], xlabel = "Strength [MPa]", ylabel = "GWP [kgCO2e/kg]")
ax1.title = "Strength vs GWP" 
# col = df[!,"country"];
scatter!(ax1, df[!,"strength [MPa]"], df[!,"gwp_per_kg [kgCO2e/kg]"], color = :red, markersize = 3)
# Legend(ax1, ["US", "CA", "AU", "NZ", "SG", "IN"])
f1

# %% [markdown]
# #### Data preparation
# 70% for training data
# <br>15% for testing data
# <br>15% for validating data

# %%
x_total = collect(df[!,"strength [MPa]"]) ; 
y_total = collect(df[!,"gwp_per_kg [kgCO2e/kg]"]) ;
data = hcat(x_total, y_total); # data is a 2 x n matrix

# %%
data
# Out:
# 119533×2 Matrix{Float64}:
#  34.4738  0.652778
#  34.4738  0.652778
#  27.579   0.636806
#  27.579   0.636806
#  34.4738  0.632212
#  41.3686  0.617561
#  34.4738  0.604167
#  34.4738  0.604167
#  34.4738  0.6
#  34.4738  0.6
#   ⋮
#  15.0     0.0317375
#  41.3685  0.03125
#  41.3685  0.03125
#  55.0     0.0304167
#  41.3685  0.0287083
#  41.3685  0.0287083
#  10.3     0.0275833
#  41.3685  0.01575
#  41.3685  0.01575

# %%
train_data, test_data = MLJ.partition(data, 0.7, multi = true, rng = 123)# rng = Random.seed!(1234))
# Out:
# ([27.57902917 0.144166667; 24.13165053 0.162916667; … ; 20.68427188 0.169166667; 24.13165053 0.139166667], [27.57902917 0.139583333; 34.47378647 0.24; … ; 20.68427188 0.117916667; 27.57902917 0.175])

# %% [markdown]
# #### Create a neural network surrogate model using Flux

# %%
N1 = Dense(1,1)
N2 = Chain(Dense(1,10,relu), Dense(10,1))
N3 = Chain(Dense(1,10,relu), Dense(10,10,relu), Dense(10,1))
N4 = Chain(Dense(1,10,relu), Dense(10,10,relu), Dense(10,10,relu), Dense(10,1))

models = [N1 , N2 , N3 , N4]

loss1(N1,(x,y)) = Flux.mse(N1(x),y)
loss2(N2,x,y) = Flux.mse(N2(x),y)
loss3(x,y) = Flux.mse(N3(x),y)
loss4(x,y) = Flux.mse(N4(x),y)

losses = [loss1, loss2, loss3, loss4]

# function my_accuracy( model , )
opt = [Descent(0.01), Descent(0.01), Descent(0.01), Descent(0.01)]
epoch = 500
opt = Adam()
# Out:
# Adam(0.001, (0.9, 0.999), 1.0e-8, IdDict{Any, Any}())

# %% [markdown]
# #### Train models and plot loss.

# %%
train_data
# Out:
# 83673×2 Matrix{Float64}:
#  27.579   0.144167
#  24.1317  0.162917
#  20.6843  0.1825
#  27.579   0.17625
#  34.4738  0.205
#  24.1317  0.109583
#  34.4738  0.19875
#  44.8159  0.167083
#  34.4738  0.127083
#  34.4738  0.125833
#   ⋮
#  31.0264  0.114167
#  34.4738  0.194583
#  27.579   0.115833
#  34.4738  0.279167
#  24.1317  0.0929167
#  27.579   0.135833
#  24.1317  0.12375
#  20.6843  0.169167
#  24.1317  0.139167

# %%
for (i, data) in enumerate(train_data)
    println("Training model $i")
    @show print("data $data")
    @show i
    @show data
end

# %%
# my_log = []
for epoch in 1:100
  global losses = Float32[]
  for (i, datai) in enumerate(train_data)
    println(i , datai)
    push!(losses, loss1(N1, datai))
    break
  end
  break
end
# data
  #   Flux.train!(loss1, Flux.params(N1), data, opt);
  #   # model[1].weight
  #   val = loss1(N1, data)

  #   # val, grads = Flux.withgradient(N1) do m
  #     # # Any code inside here is differentiated.
  #     # # Evaluation of the model and loss must be inside!
  #     # result = m(input)
  #     # loss1(result, y)
  #   end

  #   # Save the loss from the forward pass. (Done outside of gradient.)
  #   push!(losses, val)

  #   # Detect loss of Inf or NaN. Print a warning, and then skip update!
  #   if !isfinite(val)
  #     @warn "loss is $val on item $i" epoch
  #     continue
  #   end
  #   # Flux.update!(opt_state, param(N1), grads[1])
  # end

  # Compute some accuracy, and save details as a NamedTuple
  # acc = my_accuracy(model, train_set)
  # push!(my_log, (; acc, losses))

  # Stop training when some criterion is reached
  # if  acc > 0.95
  #   println("stopping after $epoch epochs")
  #   break
  # end
# end
# Out:
# BoundsError: attempt to access Float64 at index [2]
#
#
#
# Stacktrace:
#
#  [1] indexed_iterate(I::Float64, i::Int64, state::Nothing)
#
#    @ Base ./tuple.jl:97
#
#  [2] loss1(N1::Dense{typeof(identity), Matrix{Float32}, Vector{Float32}}, ::Float64)
#
#    @ Main ~/dev/CMLProject/FinalProject.ipynb:8
#
#  [3] top-level scope
#
#    @ ~/dev/CMLProject/FinalProject.ipynb:6

# %% [markdown]
# #### Plot loss

# %%
# Out:
# Float32[]

# %%
f2 = Figure(resolution = (1200, 800))
ax2= Axis(f2[1,1], xlabel = "Epoch", ylabel = "Loss")
scatter!(ax2, losses, markersize = 3)
f2

# %% [markdown]
# #### implement function to TopOpt.jl
# Since the surrogate model is a fuction that inputs fc' and outputs gwp,
# <br>we need to create a function that map fc' to E for compliance

# %%
f2e = x -> 4700*sqrt(x)
f2g = N1 #pick the model that you want to use from N1 to N5
# Out:
# Dense(1 => 1)       # 2 parameters

# %%
loss = Flux.mse
# Out:
# mse (generic function with 1 method)
